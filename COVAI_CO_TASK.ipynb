# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4c23ebbe-906a-4ee7-af25-fe9e2da4c972" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c23ebbe-906a-4ee7-af25-fe9e2da4c972">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Daily_Public_Transport_Passenger_Journeys_by_Service_Type_20241128.csv")

# %%
df.head()
# Out:
#          Date  Local Route  Light Rail  Peak Service  Rapid Route  School  \
# 0  30/08/2024        16436       10705           225        19026    3925
# 1  15/09/2023        15499       10671           267        18421    4519
# 2  28/12/2021         1756        2352             0         3775       0
# 3  11/01/2023        10536        8347           223        14072       0
# 4  11/09/2021          820         612             0         1283       0
#
#    Other
# 0   59.0
# 1   61.0
# 2   13.0
# 3   48.0
# 4   11.0

# %%
df.describe()
# Out:
#         Local Route    Light Rail  Peak Service   Rapid Route       School  \
# count   1918.000000   1918.000000   1918.000000   1918.000000  1918.000000
# mean    9891.395203   7195.446298    179.581335  12597.213243  2352.694995
# std     6120.715714   3345.616428    156.532738   6720.494557  2494.766306
# min        1.000000      0.000000      0.000000      0.000000     0.000000
# 25%     3044.500000   4463.500000      0.000000   6383.000000     0.000000
# 50%    11417.000000   7507.000000    193.000000  13106.500000   567.500000
# 75%    15517.500000  10008.250000    313.750000  17924.750000  4914.000000
# max    21070.000000  15154.000000   1029.000000  28678.000000  7255.000000
#
#              Other
# count  1898.000000
# mean     43.390411
# std      41.746882
# min       0.000000
# 25%      14.000000
# 50%      40.000000
# 75%      68.000000
# max    1105.000000

# %%
df.shape
# Out:
# (1918, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1918 entries, 0 to 1917
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1918 non-null   object
#  1   Local Route   1918 non-null   int64
#  2   Light Rail    1918 non-null   int64
#  3   Peak Service  1918 non-null   int64
#  4   Rapid Route   1918 non-null   int64
#  5   School        1918 non-null   int64
#  6   Other         1898 non-null   float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 105.0+ KB

# %%
pd.to_datetime(df["Date"])
# Out:
# <ipython-input-27-a389c144bbd3>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(df["Date"])
# 0      2024-08-30
# 1      2023-09-15
# 2      2021-12-28
# 3      2023-01-11
# 4      2021-09-11
#           ...
# 1913   2023-01-19
# 1914   2023-08-16
# 1915   2022-01-10
# 1916   2020-05-04
# 1917   2023-07-26
# Name: Date, Length: 1918, dtype: datetime64[ns]

# %% [markdown]
# # finding missing values:

# %%
df.isnull()
# Out:
#        Date  Local Route  Light Rail  Peak Service  Rapid Route  School  Other
# 0     False        False       False         False        False   False  False
# 1     False        False       False         False        False   False  False
# 2     False        False       False         False        False   False  False
# 3     False        False       False         False        False   False  False
# 4     False        False       False         False        False   False  False
# ...     ...          ...         ...           ...          ...     ...    ...
# 1913  False        False       False         False        False   False  False
# 1914  False        False       False         False        False   False  False
# 1915  False        False       False         False        False   False  False
# 1916  False        False       False         False        False   False  False
# 1917  False        False       False         False        False   False  False
#
# [1918 rows x 7 columns]

# %% [markdown]
# ## libraries for visualizing the datas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## correlation matrix:

# %%
corr_mat = df[['Local Route', 'Rapid Route', 'Peak Service', 'School']].corr()
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #histogram :

# %%
plt.hist(df["School"])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Year'] = df['Date'].dt.year

# %% [markdown]
# # histogram for schoool

# %%
plt.bar(df["Year"],df["School"])
# Out:
# <BarContainer object of 1918 artists>

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of            Date  Local Route  Light Rail  Peak Service  Rapid Route  School  \
# 0    2024-08-30        16436       10705           225        19026    3925
# 1    2023-09-15        15499       10671           267        18421    4519
# 2    2021-12-28         1756        2352             0         3775       0
# 3    2023-01-11        10536        8347           223        14072       0
# 4    2021-09-11          820         612             0         1283       0
# ...         ...          ...         ...           ...          ...     ...
# 1913 2023-01-19        11337        8671           262        14881       0
# 1914 2023-08-16        16791       11800           387        20936    4684
# 1915 2022-01-10         5732        3548            73         6644       0
# 1916 2020-05-04         3717        1952            70         4411     131
# 1917 2023-07-26        16680       11726           347        20438    4738
#
#       Other
# ...

# %% [markdown]
# ## for local route:

# %%
df["Local Route"]
# Out:
# 0       16436
# 1       15499
# 2        1756
# 3       10536
# 4         820
#         ...
# 1913    11337
# 1914    16791
# 1915     5732
# 1916     3717
# 1917    16680
# Name: Local Route, Length: 1918, dtype: int64

# %%
df["Local Route"].describe()
# Out:
# count     1918.000000
# mean      9891.395203
# std       6120.715714
# min          1.000000
# 25%       3044.500000
# 50%      11417.000000
# 75%      15517.500000
# max      21070.000000
# Name: Local Route, dtype: float64

# %%
df_local=df.groupby("Local Route")["Date"].sum().head(50)
df_local
# Out:
# Local Route
# 1       29/09/202428/09/2024
# 6                 27/09/2024
# 9                 26/09/2024
# 21      25/09/202422/09/2024
# 28                21/09/2024
# 36                24/09/2024
# 56                23/09/2024
# 61                25/12/2019
# 79                25/12/2021
# 172               25/12/2020
# 268               25/12/2022
# 315               25/12/2023
# 379               10/04/2020
# 458               05/09/2021
# 463               29/08/2021
# 485               20/09/2024
# 489               22/08/2021
# 525               15/08/2021
# 538               12/09/2021
# 563               26/09/2021
# 570               19/09/2021
# 586               12/04/2020
# 590               04/09/2021
# 594               03/10/2021
# 602               10/10/2021
# 706               29/03/2020
# 708               18/09/2021
# 720               14/08/2021
# 722               21/08/2021
# 730               04/10/2021
# 735               28/08/2021
# ...

# %%
sns.lineplot(data=df,x="Local Route",y="Year")
# Out:
# <Axes: xlabel='Local Route', ylabel='Year'>

# %% [markdown]
# ## histogram for local routes :

# %%
plt.hist(df["Local Route"])
# Out:
# (array([212., 428.,  89.,  48., 109., 199., 267., 321., 182.,  63.]),
#  array([1.00000e+00, 2.10790e+03, 4.21480e+03, 6.32170e+03, 8.42860e+03,
#         1.05355e+04, 1.26424e+04, 1.47493e+04, 1.68562e+04, 1.89631e+04,
#         2.10700e+04]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Rapid Route

# %%
df["Rapid Route"].describe()
# Out:
# count     1918.000000
# mean     12597.213243
# std       6720.494557
# min          0.000000
# 25%       6383.000000
# 50%      13106.500000
# 75%      17924.750000
# max      28678.000000
# Name: Rapid Route, dtype: float64

# %%
plt.hist(df["Rapid Route"])
# Out:
# (array([105., 265., 333., 149., 201., 304., 295., 145.,  81.,  40.]),
#  array([    0. ,  2867.8,  5735.6,  8603.4, 11471.2, 14339. , 17206.8,
#         20074.6, 22942.4, 25810.2, 28678. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df["Year"],df["Rapid Route"])
# Out:
# <BarContainer object of 1918 artists>

# %% [markdown]
# ## Peak Service

# %%
df["Peak Service"].describe()
# Out:
# count    1918.000000
# mean      179.581335
# std       156.532738
# min         0.000000
# 25%         0.000000
# 50%       193.000000
# 75%       313.750000
# max      1029.000000
# Name: Peak Service, dtype: float64

# %%
plt.hist(df["Peak Service"])
# Out:
# (array([750., 245., 418., 377., 124.,   3.,   0.,   0.,   0.,   1.]),
#  array([   0. ,  102.9,  205.8,  308.7,  411.6,  514.5,  617.4,  720.3,
#          823.2,  926.1, 1029. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df["Year"],df["Peak Service"])
# Out:
# <BarContainer object of 1918 artists>

# %% [markdown]
# ## School

# %%
df["School"].describe()
# Out:
# count    1918.000000
# mean     2352.694995
# std      2494.766306
# min         0.000000
# 25%         0.000000
# 50%       567.500000
# 75%      4914.000000
# max      7255.000000
# Name: School, dtype: float64

# %%
plt.plot(df["School"][:100],df["Year"][:100])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-2ed474b557d7> in <cell line: 1>()
# ----> 1 plt.plot(df["School"][:100],df["Year"][:100]).info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
plt.bar(df["Year"],df["School"])
# Out:
# <BarContainer object of 1918 artists>

# %% [markdown]
# ## Building a model

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# # date is converted to datetime format

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-61-b9c6864122be>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df["Date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1918 entries, 0 to 1917
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 1918 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 15.1 KB

# %% [markdown]
# ## fearture extraction

# %%
features=["Local Route","Peak Service","Rapid Route","School"]
targ=["Local Route","Peak Service","Rapid Route","School"]

# %%
x=df[features].shift(1).dropna()
x
# Out:
#       Local Route  Peak Service  Rapid Route  School
# 1         16436.0         225.0      19026.0  3925.0
# 2         15499.0         267.0      18421.0  4519.0
# 3          1756.0           0.0       3775.0     0.0
# 4         10536.0         223.0      14072.0     0.0
# 5           820.0           0.0       1283.0     0.0
# ...           ...           ...          ...     ...
# 1913       8822.0         200.0      10349.0     0.0
# 1914      11337.0         262.0      14881.0     0.0
# 1915      16791.0         387.0      20936.0  4684.0
# 1916       5732.0          73.0       6644.0     0.0
# 1917       3717.0          70.0       4411.0   131.0
#
# [1917 rows x 4 columns]

# %%
y=df[targ]

# %%
spliting=TimeSeriesSplit(n_splits=5)

# %%
model = LinearRegression()
